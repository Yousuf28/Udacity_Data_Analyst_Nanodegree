# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
trend_dallas = pd.read_csv('city_data_dallas.csv', parse_dates=True, index_col='year')

# %%
trend_dallas.head()
# Out:
#               city        country  avg_temp
# year
# 1820-01-01  Dallas  United States     16.88
# 1821-01-01  Dallas  United States     17.33
# 1822-01-01  Dallas  United States     17.87
# 1823-01-01  Dallas  United States     17.46
# 1824-01-01  Dallas  United States     17.90

# %%
trend_global = pd.read_csv('global_data.csv', parse_dates=True, index_col='year')

# %%
trend_global.head()
# Out:
#             avg_temp
# year
# 1750-01-01      8.72
# 1751-01-01      7.98
# 1752-01-01      5.78
# 1753-01-01      8.39
# 1754-01-01      8.47

# %%
unsmoothed_dallas = trend_dallas['avg_temp']['1820-01-01':'2013-01-01']
dallas_mov_avg= unsmoothed.rolling(window = 10).mean()

dallas_df = pd.DataFrame({
    'dallas_mov_avg': dallas_mov_avg, 
    'unsmoothed_dallas': unsmoothed_dallas
    
})

# %%
dallas_mov_avg.plot(figsize= (12,6))
plt.title('Dallas Trend')
# Out:
# Text(0.5,1,'Dallas Trend')

# %%
dallas_df.plot(figsize= (12,8))

# %%
trend_dallas.describe()
# Out:
#          avg_temp
# count  194.000000
# mean    18.065876
# std      0.680021
# min     16.540000
# 25%     17.612500
# 50%     18.025000
# 75%     18.437500
# max     20.450000

# %%
trend_global.describe()
# Out:
#          avg_temp
# count  266.000000
# mean     8.369474
# std      0.584747
# min      5.780000
# 25%      8.082500
# 50%      8.375000
# 75%      8.707500
# max      9.830000

# %%
unsmoothed_global = trend_global['avg_temp']['1820-01-01':'2015-01-01']
global_mov_avg= unsmoothed_global.rolling(window = 10).mean()
global_df = pd.DataFrame({
    'global_mov_avg': global_mov_avg, 
    'unsmoothed_global': unsmoothed_global
    
})

# %%
global_mov_avg.plot(figsize= (12,8))

# %%
global_df.plot(figsize= (12,8))
plt.title('Global Trend')
# Out:
# Text(0.5,1,'Global Trend')

# %%
trend_dallas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 194 entries, 1820-01-01 to 2013-01-01
# Data columns (total 3 columns):
# city        194 non-null object
# country     194 non-null object
# avg_temp    194 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 11.1+ KB

# %%
trend_compare = pd.DataFrame({
    'Global_moving_avg': global_mov_avg,
    'Dallas_moving_avg': dallas_mov_avg
})

# %%
trend_compare.plot(figsize=(12,8))

# %%
plt.subplot(2,1,1)
global_mov_avg.plot(figsize= (16,8))
plt.title('Global Trend')
plt.ylim(5,10)

plt.subplot(2,1,2)

dallas_mov_avg.plot(figsize= (16,8))
plt.title('Dallas Trend')
plt.ylim(15,21)
# Out:
# (15, 21)

# %%
global_mov_avg.plot(label="Global", legend=True, figsize=(16,8))
dallas_mov_avg.plot(secondary_y=True, label="Dallas", legend=True)
